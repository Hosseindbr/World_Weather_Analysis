# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitudes and longitudes
lats = np.random.uniform (low=-90.00, high=90.00, size=2000)
lngs=np.random.uniform(low=-180, high=180, size=2000)

# pack the random coordinates into a zip
coordinates_list = zip(lats,lngs)

coordinates_list

# %%
# create a list of random coordinates corresponding to random cities
coordinates= list(coordinates_list)
print(coordinates)
# Out:
# [(-78.81770788304244, 153.63491196836105), (74.9251017937435, 114.48775742703594), (25.79292017515857, 38.1869354022686), (57.97533958481432, 98.61566015431896), (-56.03356621305442, -105.92004680642155), (-8.191369958006149, -106.07155122573606), (62.09088537161196, -62.62581649798565), (-69.29593281182757, 54.88734070632026), (17.875603222460626, 161.79249160245354), (-15.5473096969302, -93.80607635915399), (-0.15120951492232848, -112.44676119695914), (76.94779516688598, -50.41605072181582), (19.941858051906564, -173.39568964956706), (67.04905721020677, -123.8554114076201), (15.002253386551914, -54.21746713672445), (-65.26050866273752, -78.42473126021684), (-39.19307503993617, 43.27006643214679), (59.16457422926251, 45.683690644255535), (83.88151728015626, -122.78634026098091), (31.217825452163538, -78.86142235499346), (-79.43971928022295, -68.18548462982316), (-55.72873471185993, 16.337278484167797), (58.61563197705598, 89.51650818483552), (-74.67935559107474, 159.90176012137135), (-10.0423568240261, 9.004540818893219), (50.96256921451334, 160.18179372507973), (-49.43273700147926, 176.17823075606634), (-54.64836642712642, 81.07317485859869), (12.759652507449772, -65.36818330868194), (-77.35871161231299, 147.99861955280437), (-83.32423806036218, -112.23550734151554), (-78.00243973782872, -149.99029767340693), (55.14383247182067, -87.07862938996755), (84.46151843791989, 23.263162410614626), (-67.74063974785625, -16.11728044124237), (59.94326675796458, -93.54635972290284), (3.5583179537601666, -151.15237888294263), (-62.83961707805679, 137.09098516007697), (-10.366304368131168, -11.782875735674452), (79.47135715964504, -3.8843250940657015), (-48.29639924385407, 179.95545944957826), (64.43697959674898, -71.61880344521676), (36.41510465218116, 113.9874313770897), (41.98320948137959, -105.7731620561179), (53.20344100987961, 147.15650395065865), (7.708726089233977, 79.62437850128305), (30.521211798108, -129.28752295041903), (-38.3598263629088, -100.12352733398717), (-68.79223040392789, -110.41001953323297), (21.730429397331363, -162.3579104340598), (-15.46953902712697, 6.902288301709746), (-70.88366906038331, -30.819571466328313), (84.08759572026167, -97.67984718732596), (-33.93031052191774, 94.90166931794533), (-63.4652769091922, -45.73913158265816), (-18.393352291335276, 172.31218407006418), (22.04971681864147, 100.1973847475196), (23.685299388347005, 27.264140742647243), (32.218892364747106, -135.72019096107982), (58.16321007793559, -140.96670400997272), (-25.352603437540836, 53.760123149876534), (-28.741751817541584, 126.43331524312168), (50.33981173821931, -55.13897014797098), (53.18644888751959, 128.2760286300089), (86.70258215336392, -64.84179234654555), (-56.38100863193906, -166.68352064385115), (-86.9226834059873, -52.28505247299475), (56.232805522576655, -94.14136162896045), (-81.37930095535691, 77.74675973422865), (88.17521755950122, 40.84648245350266), (51.004175341771116, -120.32128858973334), (-3.163544215599842, -171.7989235780639), (-19.671780846474178, 14.488538904028246), (-85.87498789252618, -108.47389165554915), (73.71018723504446, -72.87449581190461), (-7.701119333316086, -63.604877852776724), (14.073187028658367, -147.1646390297267), (54.312963861510354, 138.00443626505074), (-37.46239233694189, -71.07949408787329), (49.740809901974075, 30.249797245431665), (82.90441428818093, -127.9396709009913), (75.04035440433768, -40.45836719313243), (-61.338208422478516, 23.74187862963103), (-29.322414664948283, 138.82786177059836), (-6.420479036833157, -178.78732330807873), (45.39831435616617, 104.72544203293137), (73.48237535675389, -46.44519484457487), (-69.59150946472701, 127.78548476334919), (-64.01908947387659, -15.283629281407457), (59.926168370406316, 159.76168347918218), (33.72189168276779, 85.77955955754913), (-87.33108451113269, -62.44623638981375), (-14.899480310502781, 110.70730861204618), (-48.21394476030877, -18.178353491808195), (-42.921037776758354, 143.00542957551687), (35.498413902707654, 54.3333005118 ...

# %%
# Get the nearest city using the citipy module
# Create a list to hold the nearest cities
nearest_cities=[]

# detrmining the nearest city for each pair of lats and lngs
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#including unique city in the list
    if city not in nearest_cities:
        nearest_cities.append(city)
#printing the city count to see how many cities we have in the list

len(nearest_cities)
# Out:
# 726

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# indicating the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(nearest_cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(55)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_info = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_info["coord"]["lat"]
        city_lng = city_info["coord"]["lon"]
        city_country = city_info["sys"]["country"]
        city_max_temp = city_info["main"]["temp_max"]
        city_humidity = city_info["main"]["humidity"]
        city_clouds = city_info["clouds"]["all"]
        city_wind = city_info["wind"]["speed"]
        description = city_info['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_info["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | umm lajj
# Processing Record 4 of Set 1 | kodinsk
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | pangnirtung
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | coahuayana
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | bathsheba
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | pyshchug
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | mount pleasant
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | teguldet
# Processing Record 23 of Set 1 | luanda
# Processing Record 24 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 1 | dunedin
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | la asuncion
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | waipawa
# Processing Record 39 of Set 1 | iqaluit
# Processing Record 40 of Set 1 | hecun
# Processing Record 41 of Set 1 | laramie
# Processing Record 42 of Set 1 | ekhabi
# Processing Record 43 of Set 1 | kuliyapitiya
# Processing Record 44 of Set 1 | pacific grove
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | isangel
# Processing Record 50 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 2 | tahta
# Processing Record 2 of Set 2 | fortuna
# Processing Record 3 of Set 2 | haines junction
# Processing Record 4 of Set 2 | saint-pierre
# Processing Record 5 of Set 2 | yulara
# Processing Record 6 of Set 2 | lewisporte
# Processing Record 7 of Set 2 | zeya
# Processing Record 8 of Set 2 | narsaq
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 2 | kamloops
# Processing Record 12 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 2 | khorixas
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | humaita
# Processing Record 16 of Set 2 | mnogovershinnyy
# Processing Record 17 of Set 2 | coihueco
# Processing Record 18 of Set 2 | bila tserkva
# Processing Record 19 of Set 2 | tasiilaq
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | port augusta
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | mandalgovi
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | palana
# Processing Record 26 of Set 2 | jumla
# Processing Record 27 of Set 2 | boyolangu
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | burnie
# Processing Record 30 of Set 2 | damghan
# Processing Record 31 of Set 2 | dauphin
# Processing Record 32 of Set 2 | tapes
# Processing Record 33 of Set 2 | tres passos
# Processing Record 34 of Set 2 | port blair
# Processing Record 35 of Set 2 | sragen
# Processing Record 36 of Set 2 | fairbanks
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | yaqui
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | kalianget
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | sitka
# Processing Record 46 of Set 2 | labuhan
# Processing Record 47 of Set 2 | tukrah
# Processing Record 48 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | poum
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | gonen
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | grand gaube
# Processing Record 5 of Set 3 | camacha
# Processing Record 6 of Set 3 | baruun-urt
# Processing Record 7 of Set 3 | mitsamiouli
# Processing Record 8 of Set 3 | laguna
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | rikitea
# Processing Record 11 of Set 3 | nouadhibou
# Processing Record 12 of Set 3 | cayeli
# Processing Record 13 of Set 3 | ostrovnoy
# Processing Record 14 of Set 3 | srednekolymsk
# Processing Record 15 of Set 3 | albany
# Processing Record 16 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 3 | kavieng
# Processing Record 18 of Set 3 | nome
# Processing Record 19 of Set 3 | kanye
# Processing Record 20 of Set 3 | petropavl
# Processing Record 21 of Set 3 | gweta
# Processing Record 22 of Set 3 | verkhnyaya inta
# Processing Record 23 of Set 3 | vicksburg
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | abu kamal
# Processing Record 26 of Set 3 | gujrat
# Processing Record 27 of Set 3 | jacmel
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | itoman
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | bad doberan
# Processing Record 32 of Set 3 | shingu
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | naze
# Processing Record 36 of Set 3 | sogdiondon
# City not found. Skipping...
# Processing Record 37 of Set 3 | leningradskiy
# Processing Record 38 of Set 3 | huilong
# Processing Record 39 of Set 3 | bairiki
# Processing Record 40 of Set 3 | fallon
# Processing Record 41 of Set 3 | marsh harbour
# Processing Record 42 of Set 3 | chara
# Processing Record 43 of Set 3 | okhotsk
# Processing Record 44 of Set 3 | gonda
# Processing Record 45 of Set 3 | hasaki
# Processing Record 46 of Set 3 | eydhafushi
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | contai
# Processing Record 49 of Set 3 | necochea
# Processing Record 50 of Set 3 | alanya
# Processing Record 1 of Set 4 | saldanha
# Processing Record 2 of Set 4 | pacifica
# Processing Record 3 of Set 4 | mitu
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | roebourne
# Processing Record 8 of Set 4 | bambanglipuro
# Processing Record 9 of Set 4 | pevek
# Processing Record 10 of Set 4 | bandarbeyla
# Processing Record 11 of Set 4 | salinas
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | port hardy
# Processing Record 14 of Set 4 | fengcheng
# Processing Record 15 of Set 4 | kjollefjord
# Processing Record 16 of Set 4 | pecos
# Processing Record 17 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 4 | tepalcatepec
# Processing Record 19 of Set 4 | eskil
# Processing Record 20 of Set 4 | atuona
# Processing Record 21 of Set 4 | rafraf
# Processing Record 22 of Set 4 | ancud
# Processing Record 23 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 24 of Set 4 | hearst
# Processing Record 25 of Set 4 | akyab
# Processing Record 26 of Set 4 | samarai
# Processing Record 27 of Set 4 | atar
# Processing Record 28 of Set 4 | yeniseysk
# Processing Record 29 of Set 4 | port moresby
# Processing Record 30 of Set 4 | mayor pablo lagerenza
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | hima
# Processing Record 33 of Set 4 | gladstone
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | cap malheureux
# Processing Record 36 of Set 4 | gusinoye ozero
# Processing Record 37 of Set 4 | peachland
# Processing Record 38 of Set 4 | liebling
# Processing Record 39 of Set 4 | charlestown
# Processing Record 40 of Set 4 | tres lagoas
# Processing Record 41 of Set 4 | camana
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | saint george
# Processing Record 44 of Set 4 | lavumisa
# Processing Record 45 of Set 4 | vostok
# Processing Record 46 of Set 4 | deputatskiy
# Processing Record 47 of Set 4 | novoagansk
# Processing Record 48 of Set 4 | vysokogornyy
# Processing Record 49 of Set 4 | christchurch
# Processing Record 50 of Set 4 | maniitsoq
# Processing Record 1 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 5 | olinda
# Processing Record 4 of Set 5 | kishtwar
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | omboue
# Processing Record 7 of Set 5 | tecoanapa
# Processing Record 8 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 5 | hvolsvollur
# Processing Record 10 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 5 | morondava
# Processing Record 12 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | kashira
# Processing Record 15 of Set 5 | arraial do cabo
# Processing Record 16 of Set 5 | molina
# Processing Record 17 of Set 5 | muscat
# Processing Record 18 of Set 5 | skjervoy
# Processing Record 19 of Set 5 | pembroke
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | lompoc
# Processing Record 23 of Set 5 | bengkulu
# Processing Record 24 of Set 5 | constitucion
# Processing Record 25 of Set 5 | dikson
# Processing Record 26 of Set 5 | shimoda
# Processing Record 27 of Set 5 | gornyy
# Processing Record 28 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 29 of Set 5 | suntar
# Processing Record 30 of Set 5 | galle
# Processing Record 31 of Set 5 | vaitape
# Processing Record 32 of Set 5 | pemba
# Processing Record 33 of Set 5 | shumskiy
# Processing Record 34 of Set 5 | mayo
# Processing Record 35 of Set 5 | sioux lookout
# Processing Record 36 of Set 5 | inhambane
# Processing Record 37 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 5 | qaqortoq
# Processing Record 39 of Set 5 | cairns
# Processing Record 40 of Set 5 | perth
# Processing Record 41 of Set 5 | faanui
# Processing Record 42 of Set 5 | roald
# Processing Record 43 of Set 5 | macapa
# Processing Record 44 of Set 5 | mahebourg
# Processing Record 45 of Set 5 | cheremukhovo
# Processing Record 46 of Set 5 | amasya
# Processing Record 47 of Set 5 | xichang
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | imbituba
# Processing Record 50 of Set 5 | poya
# Processing Record 1 of Set 6 | orissaare
# Processing Record 2 of Set 6 | kizukuri
# Processing Record 3 of Set 6 | oistins
# Processing Record 4 of Set 6 | agapovka
# Processing Record 5 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 6 | maceio
# Processing Record 7 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 6 | kloulklubed
# Processing Record 9 of Set 6 | bethel
# Processing Record 10 of Set 6 | lixourion
# Processing Record 11 of Set 6 | veshkayma
# Processing Record 12 of Set 6 | kamsack
# Processing Record 13 of Set 6 | lagoa
# Processing Record 14 of Set 6 | vardo
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | tankhoy
# Processing Record 17 of Set 6 | hlobyne
# Processing Record 18 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 6 | adrar
# Processing Record 20 of Set 6 | severo-kurilsk
# Processing Record 21 of Set 6 | barra do corda
# Processing Record 22 of Set 6 | salalah
# Processing Record 23 of Set 6 | nyandoma
# Processing Record 24 of Set 6 | letlhakane
# Processing Record 25 of Set 6 | paamiut
# Processing Record 26 of Set 6 | la tuque
# Processing Record 27 of Set 6 | moron
# Processing Record 28 of Set 6 | sheltozero
# Processing Record 29 of Set 6 | torbay
# Processing Record 30 of Set 6 | ndioum
# Processing Record 31 of Set 6 | saint anthony
# Processing Record 32 of Set 6 | estelle
# Processing Record 33 of Set 6 | klamath falls
# Processing Record 34 of Set 6 | waingapu
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | vila velha
# Processing Record 37 of Set 6 | acari
# Processing Record 38 of Set 6 | tiznit
# Processing Record 39 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 6 | alofi
# Processing Record 41 of Set 6 | cape canaveral
# Processing Record 42 of Set 6 | umea
# Processing Record 43 of Set 6 | marsaxlokk
# Processing Record 44 of Set 6 | sayat
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | kidal
# Processing Record 48 of Set 6 | alyangula
# Processing Record 49 of Set 6 | gat
# Processing Record 50 of Set 6 | gizo
# Processing Record 1 of Set 7 | tautira
# Processing Record 2 of Set 7 | matelandia
# Processing Record 3 of Set 7 | buala
# Processing Record 4 of Set 7 | yaounde
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | san jose
# Processing Record 7 of Set 7 | cockburn town
# Processing Record 8 of Set 7 | clyde river
# Processing Record 9 of Set 7 | port macquarie
# Processing Record 10 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 7 | ust-kuyga
# Processing Record 12 of Set 7 | tamiahua
# Processing Record 13 of Set 7 | safaga
# Processing Record 14 of Set 7 | hirado
# Processing Record 15 of Set 7 | mednogorsk
# Processing Record 16 of Set 7 | takoradi
# Processing Record 17 of Set 7 | taoudenni
# Processing Record 18 of Set 7 | lazaro cardenas
# Processing Record 19 of Set 7 | gamba
# Processing Record 20 of Set 7 | kanepi
# Processing Record 21 of Set 7 | azul
# Processing Record 22 of Set 7 | cutervo
# Processing Record 23 of Set 7 | menongue
# Processing Record 24 of Set 7 | bariadi
# Processing Record 25 of Set 7 | komsomolskiy
# Processing Record 26 of Set 7 | ponta do sol
# Processing Record 27 of Set 7 | pangody
# Processing Record 28 of Set 7 | nedjo
# Processing Record 29 of Set 7 | morgan city
# Processing Record 30 of Set 7 | ust-tsilma
# Processing Record 31 of Set 7 | nova mayachka
# Processing Record 32 of Set 7 | catio
# Processing Record 33 of Set 7 | college
# Processing Record 34 of Set 7 | chitral
# Processing Record 35 of Set 7 | canutama
# Processing Record 36 of Set 7 | vung tau
# Processing Record 37 of Set 7 | udayagiri
# Processing Record 38 of Set 7 | ribeira grande
# Processing Record 39 of Set 7 | korem
# Processing Record 40 of Set 7 | sainte-rose
# Processing Record 41 of Set 7 | cayenne
# Processing Record 42 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 7 | visnes
# Processing Record 44 of Set 7 | hambantota
# Processing Record 45 of Set 7 | pasighat
# Processing Record 46 of Set 7 | lakes entrance
# Processing Record 47 of Set 7 | san patricio
# Processing Record 48 of Set 7 | chifeng
# Processing Record 49 of Set 7 | mao
# Processing Record 50 of Set 7 | neryungri
# Processing Record 1 of Set 8 | katangli
# Processing Record 2 of Set 8 | bonavista
# Processing Record 3 of Set 8 | pandan
# Processing Record 4 of Set 8 | kalmunai
# Processing Record 5 of Set 8 | abnub
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | pangoa
# Processing Record 8 of Set 8 | atbasar
# Processing Record 9 of Set 8 | rumboci
# Processing Record 10 of Set 8 | adre
# Processing Record 11 of Set 8 | ampanihy
# Processing Record 12 of Set 8 | leeton
# Processing Record 13 of Set 8 | san andres
# Processing Record 14 of Set 8 | mikhaylovka
# Processing Record 15 of Set 8 | ferme-neuve
# Processing Record 16 of Set 8 | cananeia
# Processing Record 17 of Set 8 | manggar
# Processing Record 18 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 19 of Set 8 | balaipungut
# Processing Record 20 of Set 8 | nuuk
# Processing Record 21 of Set 8 | amapa
# Processing Record 22 of Set 8 | saint-joseph
# Processing Record 23 of Set 8 | springbok
# Processing Record 24 of Set 8 | pataias
# Processing Record 25 of Set 8 | kisanga
# Processing Record 26 of Set 8 | iwanai
# Processing Record 27 of Set 8 | katsuura
# Processing Record 28 of Set 8 | saint-georges
# Processing Record 29 of Set 8 | araruna
# Processing Record 30 of Set 8 | nekrasovskaya
# Processing Record 31 of Set 8 | redlands
# Processing Record 32 of Set 8 | zunyi
# Processing Record 33 of Set 8 | souillac
# Processing Record 34 of Set 8 | broome
# Processing Record 35 of Set 8 | westport
# Processing Record 36 of Set 8 | odessa
# Processing Record 37 of Set 8 | aykhal
# Processing Record 38 of Set 8 | itarema
# Processing Record 39 of Set 8 | gopalpur
# Processing Record 40 of Set 8 | llanes
# Processing Record 41 of Set 8 | murray bridge
# Processing Record 42 of Set 8 | ponta pora
# Processing Record 43 of Set 8 | hamilton
# Processing Record 44 of Set 8 | balapulang
# Processing Record 45 of Set 8 | dongsheng
# Processing Record 46 of Set 8 | fort nelson
# Processing Record 47 of Set 8 | kuchl
# Processing Record 48 of Set 8 | makakilo city
# Processing Record 49 of Set 8 | kavaratti
# Processing Record 50 of Set 8 | rancho palos verdes
# Processing Record 1 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 9 | cabedelo
# Processing Record 3 of Set 9 | nueva loja
# Processing Record 4 of Set 9 | yar-sale
# Processing Record 5 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 9 | praia da vitoria
# Processing Record 7 of Set 9 | porto velho
# Processing Record 8 of Set 9 | kangaatsiaq
# Processing Record 9 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 9 | byron bay
# Processing Record 11 of Set 9 | cidreira
# Processing Record 12 of Set 9 | taicheng
# Processing Record 13 of Set 9 | churapcha
# Processing Record 14 of Set 9 | dhuburi
# Processing Record 15 of Set 9 | bonthe
# Processing Record 16 of Set 9 | hay river
# Processing Record 17 of Set 9 | gap
# Processing Record 18 of Set 9 | talnakh
# Processing Record 19 of Set 9 | milkovo
# Processing Record 20 of Set 9 | usinsk
# Processing Record 21 of Set 9 | riberalta
# Processing Record 22 of Set 9 | dickinson
# Processing Record 23 of Set 9 | san cristobal
# Processing Record 24 of Set 9 | bogorodsk
# Processing Record 25 of Set 9 | farafangana
# Processing Record 26 of Set 9 | terrasini
# Processing Record 27 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 9 | boundiali
# Processing Record 29 of Set 9 | luderitz
# Processing Record 30 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 9 | harper
# Processing Record 32 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 9 | padang
# Processing Record 34 of Set 9 | palmer
# Processing Record 35 of Set 9 | quatre cocos
# Processing Record 36 of Set 9 | dharchula
# Processing Record 37 of Set 9 | prince rupert
# Processing Record 38 of Set 9 | great yarmouth
# Processing Record 39 of Set 9 | grand island
# Processing Record 40 of Set 9 | pimenteiras
# Processing Record 41 of Set 9 | kigoma
# Processing Record 42 of Set 9 | le port
# Processing Record 43 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 9 | zhigansk
# Processing Record 45 of Set 9 | horizontina
# Processing Record 46 of Set 9 | bilibino
# Processing Record 47 of Set 9 | puerto baquerizo moreno
# Processing Record 48 of Set 9 | dali
# Processing Record 49 of Set 9 | airai
# Processing Record 50 of Set 9 | bilma
# Processing Record 1 of Set 10 | arlit
# Processing Record 2 of Set 10 | codrington
# Processing Record 3 of Set 10 | anadyr
# Processing Record 4 of Set 10 | wiarton
# Processing Record 5 of Set 10 | chilca
# Processing Record 6 of Set 10 | vanimo
# Processing Record 7 of Set 10 | brae
# Processing Record 8 of Set 10 | zhireken
# Processing Record 9 of Set 10 | sampit
# Processing Record 10 of Set 10 | sola
# Processing Record 11 of Set 10 | vitim
# Processing Record 12 of Set 10 | jawhar
# Processing Record 13 of Set 10 | porbandar
# Processing Record 14 of Set 10 | andra
# Processing Record 15 of Set 10 | cartagena
# Processing Record 16 of Set 10 | la ronge
# Processing Record 17 of Set 10 | yarmouth
# Processing Record 18 of Set 10 | angouleme
# Processing Record 19 of Set 10 | sao francisco de assis
# Processing Record 20 of Set 10 | tanout
# Processing Record 21 of Set 10 | tulun
# Processing Record 22 of Set 10 | meulaboh
# Processing Record 23 of Set 10 | cardston
# Processing Record 24 of Set 10 | kuytun
# Processing Record 25 of Set 10 | grimshaw
# Processing Record 26 of Set 10 | malatya
# Processing Record 27 of Set 10 | mago
# Processing Record 28 of Set 10 | avera
# Processing Record 29 of Set 10 | andenes
# Processing Record 30 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 10 | port-cartier
# Processing Record 32 of Set 10 | antofagasta
# Processing Record 33 of Set 10 | khani
# Processing Record 34 of Set 10 | faya
# Processing Record 35 of Set 10 | angoram
# Processing Record 36 of Set 10 | norrtalje
# Processing Record 37 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 38 of Set 10 | rabo de peixe
# Processing Record 39 of Set 10 | sinolon
# Processing Record 40 of Set 10 | hervey bay
# Processing Record 41 of Set 10 | verrettes
# Processing Record 42 of Set 10 | salym
# Processing Record 43 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 10 | khanpur
# Processing Record 45 of Set 10 | qena
# Processing Record 46 of Set 10 | porto-vecchio
# Processing Record 47 of Set 10 | vao
# Processing Record 48 of Set 10 | mayumba
# Processing Record 49 of Set 10 | aginskoye
# Processing Record 50 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 11 | codajas
# Processing Record 2 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 3 of Set 11 | lavrentiya
# Processing Record 4 of Set 11 | imeni poliny osipenko
# Processing Record 5 of Set 11 | auki
# Processing Record 6 of Set 11 | kathu
# Processing Record 7 of Set 11 | tema
# Processing Record 8 of Set 11 | gangapur
# Processing Record 9 of Set 11 | say
# Processing Record 10 of Set 11 | te anau
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 13 of Set 11 | marawi
# Processing Record 14 of Set 11 | mildura
# Processing Record 15 of Set 11 | leh
# Processing Record 16 of Set 11 | puerto escondido
# Processing Record 17 of Set 11 | kirkwall
# Processing Record 18 of Set 11 | rockhampton
# Processing Record 19 of Set 11 | yuzhnyy
# Processing Record 20 of Set 11 | florianopolis
# Processing Record 21 of Set 11 | yambio
# Processing Record 22 of Set 11 | paralimni
# Processing Record 23 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 24 of Set 11 | elizabeth city
# Processing Record 25 of Set 11 | barillas
# Processing Record 26 of Set 11 | shizunai
# Processing Record 27 of Set 11 | juneau
# Processing Record 28 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 29 of Set 11 | nouakchott
# Processing Record 30 of Set 11 | polunochnoye
# Processing Record 31 of Set 11 | wamba
# Processing Record 32 of Set 11 | maun
# Processing Record 33 of Set 11 | zwedru
# Processing Record 34 of Set 11 | hazleton
# Processing Record 35 of Set 11 | fereydun kenar
# Processing Record 36 of Set 11 | lumeje
# Processing Record 37 of Set 11 | ranau
# Processing Record 38 of Set 11 | jalu
# Processing Record 39 of Set 11 | inyonga
# Processing Record 40 of Set 11 | ewo
# Processing Record 41 of Set 11 | santa cruz
# Processing Record 42 of Set 11 | kuminskiy
# Processing Record 43 of Set 11 | chokwe
# Processing Record 44 of Set 11 | roma
# Processing Record 45 of Set 11 | marrakesh
# Processing Record 46 of Set 11 | wattegama
# Processing Record 47 of Set 11 | torres
# Processing Record 48 of Set 11 | mount isa
# Processing Record 49 of Set 11 | torrington
# Processing Record 50 of Set 11 | kahului
# Processing Record 1 of Set 12 | san pedro
# Processing Record 2 of Set 12 | nador
# Processing Record 3 of Set 12 | lappeenranta
# Processing Record 4 of Set 12 | crotone
# Processing Record 5 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 12 | touros
# Processing Record 7 of Set 12 | ust-barguzin
# Processing Record 8 of Set 12 | mareeba
# Processing Record 9 of Set 12 | yatou
# Processing Record 10 of Set 12 | unguia
# Processing Record 11 of Set 12 | dingle
# Processing Record 12 of Set 12 | saint-augustin
# Processing Record 13 of Set 12 | mitchell
# Processing Record 14 of Set 12 | presidencia roque saenz pena
# Processing Record 15 of Set 12 | sorland
# Processing Record 16 of Set 12 | dibulla
# Processing Record 17 of Set 12 | juybar
# Processing Record 18 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 12 | lata
# Processing Record 20 of Set 12 | vigrestad
# Processing Record 21 of Set 12 | maningrida
# Processing Record 22 of Set 12 | nim ka thana
# City not found. Skipping...
# Processing Record 23 of Set 12 | agadez
# Processing Record 24 of Set 12 | bantry
# Processing Record 25 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 26 of Set 12 | peoria
# Processing Record 27 of Set 12 | tonstad
# Processing Record 28 of Set 12 | maragogi
# Processing Record 29 of Set 12 | walsrode
# Processing Record 30 of Set 12 | gao
# Processing Record 31 of Set 12 | bowen
# Processing Record 32 of Set 12 | dovolnoye
# Processing Record 33 of Set 12 | erenhot
# Processing Record 34 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 35 of Set 12 | najran
# Processing Record 36 of Set 12 | vila
# Processing Record 37 of Set 12 | bushehr
# Processing Record 38 of Set 12 | bon air
# Processing Record 39 of Set 12 | sao filipe
# Processing Record 40 of Set 12 | jand
# Processing Record 41 of Set 12 | kununurra
# Processing Record 42 of Set 12 | fortuna foothills
# Processing Record 43 of Set 12 | nioro
# Processing Record 44 of Set 12 | ahipara
# Processing Record 45 of Set 12 | goundam
# Processing Record 46 of Set 12 | aklavik
# Processing Record 47 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 12 | road town
# Processing Record 49 of Set 12 | tigil
# Processing Record 50 of Set 12 | hobyo
# Processing Record 1 of Set 13 | okha
# Processing Record 2 of Set 13 | tahe
# Processing Record 3 of Set 13 | nara
# Processing Record 4 of Set 13 | floresta
# Processing Record 5 of Set 13 | pringsewu
# Processing Record 6 of Set 13 | boueni
# Processing Record 7 of Set 13 | camocim
# Processing Record 8 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record 9 of Set 13 | diebougou
# Processing Record 10 of Set 13 | los llanos de aridane
# Processing Record 11 of Set 13 | biak
# Processing Record 12 of Set 13 | riyadh
# Processing Record 13 of Set 13 | micheweni
# Processing Record 14 of Set 13 | almonte
# Processing Record 15 of Set 13 | doha
# Processing Record 16 of Set 13 | nileshwar
# Processing Record 17 of Set 13 | ngunguru
# Processing Record 18 of Set 13 | north platte
# Processing Record 19 of Set 13 | chimoio
# Processing Record 20 of Set 13 | kaeo
# Processing Record 21 of Set 13 | kibaya
# Processing Record 22 of Set 13 | kanniyakumari
# Processing Record 23 of Set 13 | evensk
# Processing Record 24 of Set 13 | zheshart
# Processing Record 25 of Set 13 | kaoma
# Processing Record 26 of Set 13 | tromso
# Processing Record 27 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 28 of Set 13 | flin flon
# Processing Record 29 of Set 13 | alta floresta
# Processing Record 30 of Set 13 | ginda
# Processing Record 31 of Set 13 | morant bay
# Processing Record 32 of Set 13 | kupang
# Processing Record 33 of Set 13 | vanavara
# Processing Record 34 of Set 13 | tshikapa
# Processing Record 35 of Set 13 | kralendijk
# Processing Record 36 of Set 13 | zelenoborskiy
# Processing Record 37 of Set 13 | anzhero-sudzhensk
# Processing Record 38 of Set 13 | athabasca
# Processing Record 39 of Set 13 | opuwo
# Processing Record 40 of Set 13 | ucluelet
# Processing Record 41 of Set 13 | attock
# Processing Record 42 of Set 13 | teguise
# Processing Record 43 of Set 13 | trincomalee
# Processing Record 44 of Set 13 | nur
# Processing Record 45 of Set 13 | gilgit
# Processing Record 46 of Set 13 | pachmarhi
# Processing Record 47 of Set 13 | condega
# Processing Record 48 of Set 13 | macia
# Processing Record 49 of Set 13 | shwebo
# Processing Record 50 of Set 13 | san jeronimo
# Processing Record 1 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 14 | iracoubo
# Processing Record 3 of Set 14 | pampierstad
# Processing Record 4 of Set 14 | groa
# Processing Record 5 of Set 14 | poco das trincheiras
# Processing Record 6 of Set 14 | kurchum
# Processing Record 7 of Set 14 | arman
# Processing Record 8 of Set 14 | winnemucca
# Processing Record 9 of Set 14 | muros
# Processing Record 10 of Set 14 | miasskoye
# Processing Record 11 of Set 14 | vicuna
# Processing Record 12 of Set 14 | kirakira
# Processing Record 13 of Set 14 | porto santo
# Processing Record 14 of Set 14 | obanazawa
# Processing Record 15 of Set 14 | gejiu
# Processing Record 16 of Set 14 | port lincoln
# Processing Record 17 of Set 14 | iskateley
# Processing Record 18 of Set 14 | orgun
# City not found. Skipping...
# Processing Record 19 of Set 14 | humboldt
# Processing Record 20 of Set 14 | matagami
# Processing Record 21 of Set 14 | bisho
# Processing Record 22 of Set 14 | indianola
# Processing Record 23 of Set 14 | kapuskasing
# Processing Record 24 of Set 14 | piastow
# Processing Record 25 of Set 14 | illela
# Processing Record 26 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 14 | sur
# Processing Record 28 of Set 14 | amga
# Processing Record 29 of Set 14 | mount gambier
# Processing Record 30 of Set 14 | filingue
# Processing Record 31 of Set 14 | beringovskiy
# Processing Record 32 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 14 | gotsu
# Processing Record 34 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 14 | atambua
# Processing Record 36 of Set 14 | trairi
# Processing Record 37 of Set 14 | dimona
# Processing Record 38 of Set 14 | klyuchi
# Processing Record 39 of Set 14 | amazar
# Processing Record 40 of Set 14 | maxixe
# Processing Record 41 of Set 14 | dicabisagan
# Processing Record 42 of Set 14 | hurghada
# Processing Record 43 of Set 14 | kimbe
# Processing Record 44 of Set 14 | robat karim
# Processing Record 45 of Set 14 | chapais
# Processing Record 46 of Set 14 | burica
# City not found. Skipping...
# Processing Record 47 of Set 14 | tamandare
# Processing Record 48 of Set 14 | barcelos
# Processing Record 49 of Set 14 | ratlam
# Processing Record 50 of Set 14 | contamana
# Processing Record 1 of Set 15 | riachao das neves
# Processing Record 2 of Set 15 | merauke
# Processing Record 3 of Set 15 | bereda
# Processing Record 4 of Set 15 | guangyuan
# Processing Record 5 of Set 15 | bondo
# Processing Record 6 of Set 15 | nagato
# Processing Record 7 of Set 15 | tila
# Processing Record 8 of Set 15 | hohhot
# Processing Record 9 of Set 15 | levelland
# Processing Record 10 of Set 15 | maldonado
# Processing Record 11 of Set 15 | beidao
# Processing Record 12 of Set 15 | piquete
# Processing Record 13 of Set 15 | mihail eminescu
# Processing Record 14 of Set 15 | lodja
# Processing Record 15 of Set 15 | emba
# Processing Record 16 of Set 15 | margate
# Processing Record 17 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 18 of Set 15 | muskegon
# Processing Record 19 of Set 15 | grand-santi
# Processing Record 20 of Set 15 | oliveira dos brejinhos
# Processing Record 21 of Set 15 | america dourada
# Processing Record 22 of Set 15 | caravelas
# Processing Record 23 of Set 15 | kenai
# Processing Record 24 of Set 15 | agirish
# Processing Record 25 of Set 15 | alto baudo
# City not found. Skipping...
# Processing Record 26 of Set 15 | trat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len (city_data)
# Out:
# 667

# %%
# adding  the weather data to a new DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bluff      NZ -46.6000  168.3333     42.30        68         100
# 1  Saskylakh      RU  71.9167  114.0833     50.50        72          72
# 2   Umm Lajj      SA  25.0213   37.2685     91.18        55          31
# 3    Kodinsk      RU  58.6881   99.1844     55.18        98         100
# 4     Castro      BR -24.7911  -50.0119     45.75        92          96
#
#    Wind Speed Current Description
# 0        7.92     overcast clouds
# 1       10.54       broken clouds
# 2        7.02    scattered clouds
# 3        2.80     overcast clouds
# 4       14.25     overcast clouds

# %%
# Exporting the DataFrame as WeatherPy_Database.csv into the Weather_Database folder
# defining the path
output_data_path = "Weather_Database/WeatherPy_Database.csv"

# exporting data into csv file
city_data_df.to_csv(output_data_path, index_label="city_id")
